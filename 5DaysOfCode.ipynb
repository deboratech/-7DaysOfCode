# %% [markdown]
# <a href="https://colab.research.google.com/github/deboratech/7DaysOfCode/blob/main/5DaysOfCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
import pandas as pd
import matplotlib.ticker as ticker
import numpy as np

# %% [markdown]
# ## **Coletando dos dados**

# %%
dados_2010_1 = pd.read_csv('/content/emprestimos-20101.csv')
dados_2010_2 = pd.read_csv('/content/emprestimos-20102.csv')
dados_2011_1 = pd.read_csv('/content/emprestimos-20111.csv')
dados_2011_2 = pd.read_csv('/content/emprestimos-20112.csv')
dados_2012_1 = pd.read_csv('/content/emprestimos-20121.csv')
dados_2012_2 = pd.read_csv('/content/emprestimos-20122.csv')
dados_2013_1 = pd.read_csv('/content/emprestimos-20131.csv')
dados_2013_2 = pd.read_csv('/content/emprestimos-20132.csv')
dados_2014_1 = pd.read_csv('/content/emprestimos-20141.csv')
dados_2014_2 = pd.read_csv('/content/emprestimos-20142.csv')
dados_2015_1 = pd.read_csv('/content/emprestimos-20151.csv')
dados_2015_2 = pd.read_csv('/content/emprestimos-20152.csv')
dados_2016_1 = pd.read_csv('/content/emprestimos-20161.csv')
dados_2016_2 = pd.read_csv('/content/emprestimos-20162.csv')
dados_2017_1 = pd.read_csv('/content/emprestimos-20171.csv')
dados_2017_2 = pd.read_csv('/content/emprestimos-20172.csv')
dados_2018_1 = pd.read_csv('/content/emprestimos-20181.csv')
dados_2018_2 = pd.read_csv('/content/emprestimos-20182.csv')
dados_2019_1 = pd.read_csv('/content/emprestimos-20191.csv')
dados_2019_2 = pd.read_csv('/content/emprestimos-20192.csv')
dados_2020_1 = pd.read_csv('/content/emprestimos-20201.csv')

# %% [markdown]
# ## **Concatenando os DataFrames**

# %%
emprestimos_biblioteca = [dados_2010_2, dados_2010_1, dados_2011_1, dados_2011_2, dados_2012_1, dados_2012_2, dados_2013_1, dados_2013_2, dados_2014_1, dados_2014_2, dados_2015_1, dados_2015_2, dados_2016_1, dados_2016_2, dados_2017_1, dados_2017_2, dados_2018_1, dados_2018_2, dados_2019_1, dados_2019_2, dados_2020_1]

# %%
emprestimos_biblioteca = pd.concat(emprestimos_biblioteca)

# %%
emprestimos_biblioteca
# Out:
#        id_emprestimo                codigo_barras  \
# 0             799100  S025602_19/11/2013 10:51:34
# 1             799101                   2008049500
# 2             799102                      X008043
# 3             799103                   2009055438
# 4             799104                      S024636
# ...              ...                          ...
# 26556        2989086                   2008047044
# 26557        2989087                   2008047047
# 26558        2989088                   2010052905
# 26559        2989089                   2010048023
# 26560        2989090                   2013106838
#
#                       data_renovacao                data_emprestimo  \
# 0                                NaN  2010/07/01 07:45:41.111000000
# 1                                NaN  2010/07/01 08:08:17.690000000
# 2                                NaN  2010/07/01 08:13:31.574000000
# 3      2010/07/14 18:35:35.042000000  2010/07/01 08:22:46.085000000
# ...

# %% [markdown]
# ## **Verificando informações sobre o DataFrame**

# %%
emprestimos_biblioteca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258018 entries, 0 to 26560
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 137.8+ MB

# %% [markdown]
# ## **Verificando dados duplicados**

# %%
emprestimos_biblioteca.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %%
duplicados = emprestimos_biblioteca.duplicated()

# %%
duplicados.sum()
# Out:
# 37

# %% [markdown]
# ## **Excluindo dados duplicados**

# %%
emprestimos_biblioteca = emprestimos_biblioteca.drop_duplicates()

# %% [markdown]
# ## **Verificando dados nulos**

# %%
emprestimos_biblioteca.isnull().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1285709
# data_emprestimo               0
# data_devolucao             6471
# matricula_ou_siape         3170
# tipo_vinculo_usuario          0
# dtype: int64

# %% [markdown]
# ## **Importando dados exemplares**

# %%
dados_exemplares = pd.read_parquet('/content/dados_exemplares.parquet')

# %% [markdown]
# ## **Verificando informações do DataFrame**

# %%
dados_exemplares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 546237 entries, 0 to 568584
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_exemplar       546237 non-null  int64
#  1   codigo_barras     546237 non-null  object
#  2   colecao           546237 non-null  object
#  3   biblioteca        546237 non-null  object
#  4   status_material   546237 non-null  object
#  5   localizacao       546237 non-null  int64
#  6   registro_sistema  546237 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 33.3+ MB

# %% [markdown]
# ## **Verificando dados duplicados**

# %%
dados_exemplares.value_counts()
# Out:
# id_exemplar  codigo_barras  colecao            biblioteca                                             status_material  localizacao  registro_sistema
# 3            L000001        Acervo Circulante  Biblioteca Central Zila Mamede                         ESPECIAL         638          1                   1
# 1070480      2013071582     Acervo Circulante  Biblioteca Setorial do Centro Ciências da Saúde - CCS  REGULAR          340          200283              1
# 1070506      2013077711     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          354          200288              1
# 1070505      2013077710     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          327          200288              1
# 1070504      2013077807     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          348          200286              1
# ...

# %%
duplicados_dados_exemplares = dados_exemplares.duplicated()
duplicados_dados_exemplares.sum()
# Out:
# 0

# %% [markdown]
# ## **Verificando dados nulos**

# %%
dados_exemplares.isnull().sum()
# Out:
# id_exemplar         0
# codigo_barras       0
# colecao             0
# biblioteca          0
# status_material     0
# localizacao         0
# registro_sistema    0
# dtype: int64

# %% [markdown]
# ## **Unindo os DataFrames**

# %%
emprestimos_completos = pd.merge(emprestimos_biblioteca, dados_exemplares)

# %%
emprestimos_completos
# Out:
#          id_emprestimo                codigo_barras  \
# 0               799100  S025602_19/11/2013 10:51:34
# 1               809804  S025602_19/11/2013 10:51:34
# 2               826521  S025602_19/11/2013 10:51:34
# 3               831124  S025602_19/11/2013 10:51:34
# 4               839249  S025602_19/11/2013 10:51:34
# ...                ...                          ...
# 2072517        2989018                   2009036492
# 2072518        2989020                   2014062640
# 2072519        2989032                   2018003324
# 2072520        2989049                   2006024313
# 2072521        2989061                   2018031352
#
#                         data_renovacao                data_emprestimo  \
# 0                                  NaN  2010/07/01 07:45:41.111000000
# 1        2010/08/10 20:36:21.378000000  2010/08/09 14:32:14.211000000
# 2                                  NaN  2010/08/30 17:06:09.807000000
# ...

# %% [markdown]
# ## **Verificando informações do DataFrame**

# %%
emprestimos_completos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072522 entries, 0 to 2072521
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  registro_sistema      int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 205.6+ MB

# %% [markdown]
# ## **Definindo o nome da coluna conforme a Classificação Decimal Universal (CDU)**

# %%
CDU_lista = []
for CDU in emprestimos_completos['localizacao']:
  if(CDU < 100):
    CDU_lista.append('Generalidades')
  elif(CDU < 200):
    CDU_lista.append('Filosofia e psicologia')
  elif(CDU < 300):
    CDU_lista.append('Religião')
  elif(CDU < 400):
    CDU_lista.append('Ciências sociais')
  elif(CDU < 500):
    CDU_lista.append('Classe vaga')
  elif(CDU < 600):
    CDU_lista.append('Matemática e ciências naturais')
  elif(CDU < 700):
    CDU_lista.append('Ciências aplicadas')
  elif(CDU < 800):
    CDU_lista.append('Belas artes')
  elif(CDU < 900):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia. Biografia. História.')

emprestimos_completos['CDU_geral'] = CDU_lista

# %%
emprestimos_completos
# Out:
#          id_emprestimo                codigo_barras  \
# 0               799100  S025602_19/11/2013 10:51:34
# 1               809804  S025602_19/11/2013 10:51:34
# 2               826521  S025602_19/11/2013 10:51:34
# 3               831124  S025602_19/11/2013 10:51:34
# 4               839249  S025602_19/11/2013 10:51:34
# ...                ...                          ...
# 2072517        2989018                   2009036492
# 2072518        2989020                   2014062640
# 2072519        2989032                   2018003324
# 2072520        2989049                   2006024313
# 2072521        2989061                   2018031352
#
#                         data_renovacao                data_emprestimo  \
# 0                                  NaN  2010/07/01 07:45:41.111000000
# 1        2010/08/10 20:36:21.378000000  2010/08/09 14:32:14.211000000
# 2                                  NaN  2010/08/30 17:06:09.807000000
# ...

# %% [markdown]
# ## **Deletando coluna 'registro_sistema'**

# %%
emprestimos_completos.drop(columns=['registro_sistema'], inplace= True)

# %% [markdown]
# ## **Modificando o tipo de dado da coluna 'matricula'**

# %%
emprestimos_completos['matricula_ou_siape'] = emprestimos_completos['matricula_ou_siape'].astype(str)

# %%
emprestimos_completos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072522 entries, 0 to 2072521
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    object
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  CDU_geral             object
# dtypes: int64(3), object(10)
# memory usage: 205.6+ MB

# %% [markdown]
# ## **Modificando o tipo de dado das datas de empréstimo, renovação e devolução**

# %%
emprestimos_completos['data_emprestimo'] = pd.to_datetime(emprestimos_completos['data_emprestimo'])
emprestimos_completos['data_renovacao'] = pd.to_datetime(emprestimos_completos['data_renovacao'])
emprestimos_completos['data_devolucao'] = pd.to_datetime(emprestimos_completos['data_devolucao'])

# %%
display(emprestimos_completos)
# Out:
#          id_emprestimo                codigo_barras          data_renovacao  \
# 0               799100  S025602_19/11/2013 10:51:34                     NaT
# 1               809804  S025602_19/11/2013 10:51:34 2010-08-10 20:36:21.378
# 2               826521  S025602_19/11/2013 10:51:34                     NaT
# 3               831124  S025602_19/11/2013 10:51:34                     NaT
# 4               839249  S025602_19/11/2013 10:51:34                     NaT
# ...                ...                          ...                     ...
# 2072517        2989018                   2009036492                     NaT
# 2072518        2989020                   2014062640                     NaT
# 2072519        2989032                   2018003324                     NaT
# 2072520        2989049                   2006024313                     NaT
# 2072521        2989061                   2018031352                     NaT
#
# ...

# %%
emprestimos_completos.head()
# Out:
#    id_emprestimo                codigo_barras          data_renovacao  \
# 0         799100  S025602_19/11/2013 10:51:34                     NaT
# 1         809804  S025602_19/11/2013 10:51:34 2010-08-10 20:36:21.378
# 2         826521  S025602_19/11/2013 10:51:34                     NaT
# 3         831124  S025602_19/11/2013 10:51:34                     NaT
# 4         839249  S025602_19/11/2013 10:51:34                     NaT
#
#           data_emprestimo      data_devolucao matricula_ou_siape  \
# 0 2010-07-01 07:45:41.111 2010-07-07 10:52:31       2009049900.0
# 1 2010-08-09 14:32:14.211 2010-08-30 17:04:59       2008035310.0
# 2 2010-08-30 17:06:09.807 2010-09-03 08:13:44       2008035077.0
# 3 2010-09-08 11:07:07.699 2010-09-15 07:34:37        200734334.0
# 4 2010-09-17 10:47:36.670 2010-10-05 16:33:03       2009054385.0
#
#   tipo_vinculo_usuario  id_exemplar            colecao  \
# 0   ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# ...

# %% [markdown]
# ## **Perguntas e Respostas**

# %% [markdown]
# **A diretoria da biblioteca gostaria de entender se a quantidade de empréstimos está diminuindo, aumentando ou permanecendo igual ao decorrer dos últimos anos.**

# %%
emprestimos_completos['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 2422542     3
# 2595954     3
# 2049407     3
# 2014596     3
# 10240112    3
#            ..
# 766935      1
# 945676      1
# 766931      1
# 2282758     1
# 2989061     1
# Name: count, Length: 2068724, dtype: int64

# %%
emprestimos_completos['id_emprestimo'].drop_duplicates()
# Out:
# 0           799100
# 1           809804
# 2           826521
# 3           831124
# 4           839249
#             ...
# 2072517    2989018
# 2072518    2989020
# 2072519    2989032
# 2072520    2989049
# 2072521    2989061
# Name: id_emprestimo, Length: 2068724, dtype: int64

# %%
emprestimos_data = pd.DataFrame(emprestimos_completos['data_emprestimo'].value_counts()).reset_index()
emprestimos_data.columns = ['data','quantidade']
emprestimos_data['data'] = pd.to_datetime(emprestimos_data['data'])
emprestimos_data
# Out:
#                            data  quantidade
# 0       2015-06-10 18:51:56.994           3
# 1       2015-08-18 19:11:08.653           3
# 2       2014-01-28 14:49:50.505           3
# 3       2015-05-05 20:37:19.551           3
# 4       2017-09-20 16:47:09.285           3
# ...                         ...         ...
# 2068686 2018-03-02 16:16:10.811           1
# 2068687 2010-04-30 16:43:18.840           1
# 2068688 2018-04-18 16:53:33.503           1
# 2068689 2018-03-13 20:48:59.624           1
# 2068690 2020-03-17 21:22:22.138           1
#
# [2068691 rows x 2 columns]

# %%
emprestimos_ano = emprestimos_data.groupby(by=emprestimos_data['data'].dt.year).size()
emprestimos_ano.index.name = 'ano'
emprestimos_ano
# Out:
# ano
# 2010    161277
# 2011    196199
# 2012    221141
# 2013    234431
# 2014    218765
# 2015    213117
# 2016    215411
# 2017    217974
# 2018    193547
# 2019    171296
# 2020     25533
# dtype: int64

# %%
estatísticas = emprestimos_ano.describe().round(1)
print(estatísticas)
# Out:
# count        11.0
# mean     188062.8
# std       58282.0
# min       25533.0
# 25%      182421.5
# 50%      213117.0
# 75%      218369.5
# max      234431.0
# dtype: float64

# %%
emprestimos_ano = emprestimos_data.groupby(by=emprestimos_data['data'].dt.year).size()
emprestimos_ano.index.name = 'ano'
emprestimos_qntd = emprestimos_ano.reset_index(name='quantidade')

sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=emprestimos_qntd, x='ano', y='quantidade', marker='o', color='g')
plt.title('Número de Empréstimos por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Empréstimos')
plt.show()

# %% [markdown]
# **A diretoria também gostaria de gerenciar melhor os recursos humanos da biblioteca de acordo com a demanda de trabalho existente. Por exemplo:**
#
# *  gerenciar a programação de férias dos colaboradores de acordo com os meses de menor demanda;
# *   programar atividades que não sejam de atendimento ao usuário para períodos específicos de menor demanda.

# %%
emprestimos_mes = emprestimos_data.groupby(by=emprestimos_data['data'].dt.month).size()
emprestimos_mes.index.name = 'mes'
emprestimos_mes
# Out:
# mes
# 1      67391
# 2     209839
# 3     251710
# 4     208339
# 5     202139
# 6     137815
# 7     123588
# 8     232371
# 9     207875
# 10    188076
# 11    163907
# 12     75641
# dtype: int64

# %%
dicionario_mes = {1:'Jan',2:'Fev',3:'Mar',4:'Abr',
                    5:'Mai',6:'Jun',7:'Jul',8:'Ago',
                    9:'Set',10:'Out',11:'Nov',12:'Dez'}
# Out:
# mes
# 1      67391
# 2     209839
# 3     251710
# 4     208339
# 5     202139
# 6     137815
# 7     123588
# 8     232371
# 9     207875
# 10    188076
# 11    163907
# 12     75641
# dtype: int64

# %%
emprestimos_mes.index = emprestimos_mes.index.map(dicionario_mes)
emprestimos_mes
# Out:
# mes
# Jan     67391
# Fev    209839
# Mar    251710
# Abr    208339
# Mai    202139
# Jun    137815
# Jul    123588
# Ago    232371
# Set    207875
# Out    188076
# Nov    163907
# Dez     75641
# dtype: int64

# %%
estatísticas_mes = emprestimos_mes.describe().round(1)
estatísticas_mes
# Out:
# count        12.0
# mean     172390.9
# std       59550.3
# min       67391.0
# 25%      134258.2
# 50%      195107.5
# 75%      208714.0
# max      251710.0
# dtype: float64

# %%
emprestimos_mes = emprestimos_data.groupby(by=emprestimos_data['data'].dt.month).size()
emprestimos_mes.index.name = 'mes'
emprestimos_mes

sns.set_palette("colorblind")

plt.figure(figsize=(10, 6))
sns.barplot(x=emprestimos_mes.index, y=emprestimos_mes.values)
plt.title('Número de Empréstimos por Mês')
plt.xlabel('Mês')
plt.ylabel('Quantidade de Empréstimos')
plt.xticks(rotation=45)
plt.show()

# %%
emprestimos_horario = emprestimos_data.groupby(by=emprestimos_data['data'].dt.hour).size()
emprestimos_horario.index.name = 'horário'
emprestimos_horario
# Out:
# horário
# 0         17
# 6         14
# 7      18735
# 8     103226
# 9     131032
# 10    185457
# 11    179713
# 12    148459
# 13    126756
# 14    150571
# 15    166369
# 16    210264
# 17    184967
# 18    182227
# 19    101959
# 20    127519
# 21     51109
# 22       247
# 23        50
# dtype: int64

# %%
emprestimos_horario_sorted = emprestimos_horario.sort_values(ascending=False)
horarios_mais_emprestimos = emprestimos_horario_sorted.head(5)
horarios_mais_emprestimos
# Out:
# horário
# 16    210264
# 10    185457
# 17    184967
# 18    182227
# 11    179713
# dtype: int64

# %%
emprestimos_horario_sorted = emprestimos_horario.sort_values(ascending=False)
horarios_mais_emprestimos = emprestimos_horario_sorted.head(5)
horarios_mais_emprestimos

colors = ['pink', 'lightcoral', 'lightskyblue', 'lightgreen', 'orange']

plt.figure(figsize=(6, 6))
plt.pie(horarios_mais_emprestimos, labels=horarios_mais_emprestimos.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Horários com Mais Empréstimos')
plt.show()

# %% [markdown]
# ## **Verificando valores únicos das variáveis**

# %%
emprestimos_completos.tipo_vinculo_usuario.unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'SERVIDOR TÉCNICO-ADMINISTRATIVO', 'DOCENTE EXTERNO',
#        'USUÁRIO EXTERNO', 'ALUNO MÉDIO/TÉCNICO', 'OUTROS'], dtype=object)

# %%
emprestimos_completos.colecao.unique()
# Out:
# array(['Acervo Circulante', 'Obras de Referência', 'Monografias',
#        'Dissertações', 'Publicações de Autores do RN', 'Multimeios',
#        'Folhetos', 'Teses', 'Publicações da UFRN', 'Eventos',
#        'Coleção Mossoroense', 'Trabalho Acadêmico', 'Coleção Zila Mamede',
#        'Obras Raras', 'Literatura de Cordel',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
emprestimos_completos.biblioteca.unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Moacyr de Góes - CE',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Pe. Jaime Diniz - Escola de Música - EMUFRN',
# ...

# %%
emprestimos_completos.CDU_geral.unique()
# Out:
# array(['Ciências aplicadas', 'Ciências sociais', 'Generalidades',
#        'Linguagem', 'Filosofia e psicologia',
#        'Geografia. Biografia. História.', 'Belas artes',
#        'Matemática e ciências naturais', 'Religião'], dtype=object)

# %% [markdown]
# ## **Criando função para uma tabela de frequência**

# %%
def tabela_frequencia(variavel):

  dataframe = pd.DataFrame(emprestimos_completos[variavel].value_counts())
  dataframe.columns = ['quantidade']
  dataframe['percentual'] = round((dataframe.quantidade / dataframe.quantidade.sum())*100,1)

  return dataframe

# %% [markdown]
# **Como se distribuem os empréstimos de exemplares pelos tipos de vínculo dos usuários?**

# %%
tabela_frequencia('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1612324        77.8
# ALUNO DE PÓS-GRADUAÇÃO               302541        14.6
# DOCENTE                               70981         3.4
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184         1.6
# ALUNO MÉDIO/TÉCNICO                   28029         1.4
# DOCENTE EXTERNO                       23949         1.2
# USUÁRIO EXTERNO                        2509         0.1
# OUTROS                                    5         0.0

# %% [markdown]
# **Quais coleções são mais emprestadas?**

# %%
tabela_frequencia('colecao')
# Out:
#                                        quantidade  percentual
# colecao
# Acervo Circulante                         2053120        99.1
# Multimeios                                   7954         0.4
# Monografias                                  4021         0.2
# Dissertações                                 2406         0.1
# Obras de Referência                          1954         0.1
# Publicações de Autores do RN                  866         0.0
# Publicações da UFRN                           764         0.0
# Teses                                         714         0.0
# Folhetos                                      271         0.0
# Necessidades Educacionais Específicas         130         0.0
# Trabalho Acadêmico                            115         0.0
# Eventos                                       101         0.0
# Coleção Mossoroense                            44         0.0
# Coleção Zila Mamede                            30         0.0
# ...

# %% [markdown]
# **Quais são as bibliotecas com mais ou menos quantidade de empréstimos?**

# %%
tabela_frequencia('biblioteca')
# Out:
#                                                     quantidade  percentual
# biblioteca
# Biblioteca Central Zila Mamede                         1426122        68.8
# Biblioteca Setorial do Centro Ciências da Saúde...      118614         5.7
# Biblioteca Setorial da Faculdade de Ciências da...       77609         3.7
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447         3.2
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478         3.0
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040         2.2
# Biblioteca Setorial do Centro de Ciências Human...       40744         2.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097         1.5
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089         1.4
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219         1.3
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923         1.3
# ...

# %% [markdown]
# **De quais temas da CDU são os exemplares emprestados?**

# %%
tabela_frequencia('CDU_geral')
# Out:
#                                  quantidade  percentual
# CDU_geral
# Ciências aplicadas                  1425473        68.8
# Ciências sociais                     369536        17.8
# Matemática e ciências naturais        68744         3.3
# Generalidades                         62521         3.0
# Religião                              62295         3.0
# Filosofia e psicologia                60563         2.9
# Geografia. Biografia. História.        7989         0.4
# Belas artes                            7911         0.4
# Linguagem                              7490         0.4

# %% [markdown]
# **Avaliar dentre os alunos de graduação e pós graduação a distribuição de empréstimos mensais por ano realizados entre 2010 e 2020 da coleção que tiver a maior frequência de empréstimos.**

# %% [markdown]
# # Alunos de Graduação

# %%
alunos_graduacao = emprestimos_completos.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %% [markdown]
# ## **Criando tabela com a quantidade mensal por ano**

# %%
alunos_graduacao_acervo_circulante = alunos_graduacao.query('colecao == "Acervo Circulante"')
alunos_graduacao_acervo_circulante = pd.DataFrame(alunos_graduacao_acervo_circulante)
alunos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_graduacao_acervo_circulante['data_emprestimo'])
alunos_graduacao_acervo_circulante['ano'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_graduacao_acervo_circulante['mes'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 118  2016    1        2670
# 119  2019    1        2276
# 120  2019   12        1980
# 121  2020    1        1781
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %% [markdown]
# ## **Criando função que gera box_plt**

# %%
def gera_box_plot(dataset, x, y, titulo, subtitulo):

  sns.set_theme(style="darkgrid", palette='Paired',font_scale=1.3)
  plt.figure(figsize=(16,10))

  ax = sns.boxplot(y= y, x= x, data= dataset,color='red')
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))


  plt.ylim(0,max(dataset[y])*1.1)
  plt.xlabel(None)
  plt.ylabel(None)

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %%
gera_box_plot(alunos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos Empréstimos Mensais', 'Realizados pelos alunos de graduação no acervo circulante')

# %% [markdown]
# ## Alunos de pós-graduação

# %%
alunos_pos_graduacao = emprestimos_completos.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
alunos_pos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        299201
# Dissertações                                934
# Obras de Referência                         700
# Multimeios                                  559
# Teses                                       367
# Monografias                                 278
# Publicações de Autores do RN                204
# Publicações da UFRN                         121
# Folhetos                                     60
# Necessidades Educacionais Específicas        30
# Eventos                                      26
# Coleção Mossoroense                          23
# Trabalho Acadêmico                           23
# Coleção Zila Mamede                          11
# Literatura de Cordel                          4
# Name: count, dtype: int64

# %% [markdown]
# ## **Criando tabela com a quantidade mensal por ano**

# %%
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao.query('colecao == "Acervo Circulante"')
alunos_pos_graduacao_acervo_circulante = pd.DataFrame(alunos_pos_graduacao_acervo_circulante)
alunos_pos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_pos_graduacao_acervo_circulante['data_emprestimo'])
alunos_pos_graduacao_acervo_circulante['ano'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_pos_graduacao_acervo_circulante['mes'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_pos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2015    3        3927
# 1    2017    8        3837
# 2    2017    3        3722
# 3    2016    3        3711
# 4    2016    8        3662
# ..    ...  ...         ...
# 119  2020    1        1143
# 120  2010    1        1105
# 121  2019   12        1069
# 122  2011    1         465
# 123  2020    6           2
#
# [124 rows x 3 columns]

# %%
gera_box_plot(alunos_pos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos Empréstimos Mensais', 'Realizados pelos alunos de pós graduação no acervo circulante')
