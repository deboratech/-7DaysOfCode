# %% [markdown]
# <a href="https://colab.research.google.com/github/deboratech/7DaysOfCode/blob/main/3DaysOfCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## **Coletando dos dados**

# %%
dados_2010_1 = pd.read_csv('/content/emprestimos-20101.csv')
dados_2010_2 = pd.read_csv('/content/emprestimos-20102.csv')
dados_2011_1 = pd.read_csv('/content/emprestimos-20111.csv')
dados_2011_2 = pd.read_csv('/content/emprestimos-20112.csv')
dados_2012_1 = pd.read_csv('/content/emprestimos-20121.csv')
dados_2012_2 = pd.read_csv('/content/emprestimos-20122.csv')
dados_2013_1 = pd.read_csv('/content/emprestimos-20131.csv')
dados_2013_2 = pd.read_csv('/content/emprestimos-20132.csv')
dados_2014_1 = pd.read_csv('/content/emprestimos-20141.csv')
dados_2014_2 = pd.read_csv('/content/emprestimos-20142.csv')
dados_2015_1 = pd.read_csv('/content/emprestimos-20151.csv')
dados_2015_2 = pd.read_csv('/content/emprestimos-20152.csv')
dados_2016_1 = pd.read_csv('/content/emprestimos-20161.csv')
dados_2016_2 = pd.read_csv('/content/emprestimos-20162.csv')
dados_2017_1 = pd.read_csv('/content/emprestimos-20171.csv')
dados_2017_2 = pd.read_csv('/content/emprestimos-20172.csv')
dados_2018_1 = pd.read_csv('/content/emprestimos-20181.csv')
dados_2018_2 = pd.read_csv('/content/emprestimos-20182.csv')
dados_2019_1 = pd.read_csv('/content/emprestimos-20191.csv')
dados_2019_2 = pd.read_csv('/content/emprestimos-20192.csv')
dados_2020_1 = pd.read_csv('/content/emprestimos-20201.csv')

# %% [markdown]
# ## **Concatenando os DataFrames**

# %%
emprestimos_biblioteca = [dados_2010_2, dados_2010_1, dados_2011_1, dados_2011_2, dados_2012_1, dados_2012_2, dados_2013_1, dados_2013_2, dados_2014_1, dados_2014_2, dados_2015_1, dados_2015_2, dados_2016_1, dados_2016_2, dados_2017_1, dados_2017_2, dados_2018_1, dados_2018_2, dados_2019_1, dados_2019_2, dados_2020_1]

# %%
emprestimos_biblioteca = pd.concat(emprestimos_biblioteca)

# %%
emprestimos_biblioteca
# Out:
#        id_emprestimo                codigo_barras  \
# 0             799100  S025602_19/11/2013 10:51:34
# 1             799101                   2008049500
# 2             799102                      X008043
# 3             799103                   2009055438
# 4             799104                      S024636
# ...              ...                          ...
# 26556        2989086                   2008047044
# 26557        2989087                   2008047047
# 26558        2989088                   2010052905
# 26559        2989089                   2010048023
# 26560        2989090                   2013106838
#
#                       data_renovacao                data_emprestimo  \
# 0                                NaN  2010/07/01 07:45:41.111000000
# 1                                NaN  2010/07/01 08:08:17.690000000
# 2                                NaN  2010/07/01 08:13:31.574000000
# 3      2010/07/14 18:35:35.042000000  2010/07/01 08:22:46.085000000
# 4      2010/07/16 21:29:43.569000000  2010/07/01 08:40:28.512000000
# ...                              ...                            ...
# 26556                            NaN  2020/05/05 19:51:06.059000000
# 26557                            NaN  2020/05/05 19:51:06.135000000
# 26558                            NaN  2020/05/05 19:51:06.164000000
# 26559                            NaN  2020/06/09 11:54:02.669000000
# 26560                            NaN  2020/06/09 11:54:02.852000000
#
#                       data_devolucao  matricula_ou_siape  \
# 0      2010/07/07 10:52:31.000000000        2.009050e+09
# 1      2010/07/01 09:03:44.000000000        2.010056e+09
# 2      2010/07/09 15:14:44.000000000        2.009043e+09
# 3      2010/07/29 14:59:16.000000000        2.009054e+09
# 4      2010/07/28 07:49:32.000000000        2.009054e+09
# ...                              ...                 ...
# 26556  2021/05/13 14:53:31.000000000        3.067431e+06
# 26557  2021/05/13 14:53:38.000000000        3.067431e+06
# 26558  2021/05/13 15:01:46.000000000        3.067431e+06
# 26559  2021/07/21 15:33:55.000000000        2.020101e+10
# 26560  2021/07/21 15:33:45.000000000        2.020101e+10
#
#                   tipo_vinculo_usuario
# 0                   ALUNO DE GRADUAÇÃO
# 1                   ALUNO DE GRADUAÇÃO
# 2                   ALUNO DE GRADUAÇÃO
# 3                   ALUNO DE GRADUAÇÃO
# 4                   ALUNO DE GRADUAÇÃO
# ...                                ...
# 26556  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 26557  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 26558  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 26559           ALUNO DE PÓS-GRADUAÇÃO
# 26560           ALUNO DE PÓS-GRADUAÇÃO
#
# [2258018 rows x 7 columns]

# %% [markdown]
# ## **Verificando informações sobre o DataFrame**

# %%
emprestimos_biblioteca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258018 entries, 0 to 26560
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 137.8+ MB

# %% [markdown]
# ## **Verificando dados duplicados**

# %%
emprestimos_biblioteca.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# 2461099        2012008348     2016/06/27 20:35:46.855000000  2016/06/14 11:20:33.254000000  2016/07/11 14:37:29.000000000  2.015022e+09        ALUNO DE GRADUAÇÃO        2
#                                                                                                                                                                         ..
# 1443389        2011018954     2013/03/22 13:18:55.037000000  2013/03/07 11:21:26.480000000  2013/04/08 20:26:07.000000000  2.010046e+09        ALUNO DE GRADUAÇÃO        1
# 1443390        2009056314     2013/03/21 09:28:45.689000000  2013/03/07 11:21:28.899000000  2013/04/05 18:18:00.000000000  2.011015e+09        ALUNO DE GRADUAÇÃO        1
# 1443393        2012037906     2013/03/20 20:17:10.574000000  2013/03/07 11:24:19.326000000  2013/03/25 08:58:44.000000000  2.011038e+09        ALUNO DE GRADUAÇÃO        1
# 1443395        2011033069     2013/04/07 01:06:51.679000000  2013/03/07 11:25:22.661000000  2013/05/07 16:19:34.000000000  2.011106e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 10322328       2014070441     2018/01/15 12:26:00.697000000  2017/12/29 18:21:09.060000000  2018/01/31 18:50:25.000000000  2.014063e+09        ALUNO DE GRADUAÇÃO        1
# Name: count, Length: 968028, dtype: int64

# %%
duplicados = emprestimos_biblioteca.duplicated()

# %%
duplicados.sum()
# Out:
# 37

# %% [markdown]
# ## **Excluindo dados duplicados**

# %%
emprestimos_biblioteca = emprestimos_biblioteca.drop_duplicates()

# %% [markdown]
# ## **Verificando dados nulos**

# %%
emprestimos_biblioteca.isnull().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1285709
# data_emprestimo               0
# data_devolucao             6471
# matricula_ou_siape         3170
# tipo_vinculo_usuario          0
# dtype: int64

# %% [markdown]
# ## **Importando dados exemplares**

# %%
dados_exemplares = pd.read_parquet('/content/dados_exemplares.parquet')

# %% [markdown]
# ## **Verificando informações do DataFrame**

# %%
dados_exemplares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 546237 entries, 0 to 568584
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_exemplar       546237 non-null  int64
#  1   codigo_barras     546237 non-null  object
#  2   colecao           546237 non-null  object
#  3   biblioteca        546237 non-null  object
#  4   status_material   546237 non-null  object
#  5   localizacao       546237 non-null  int64
#  6   registro_sistema  546237 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 33.3+ MB

# %% [markdown]
# ## **Verificando dados duplicados**

# %%
dados_exemplares.value_counts()
# Out:
# id_exemplar  codigo_barras  colecao            biblioteca                                             status_material  localizacao  registro_sistema
# 3            L000001        Acervo Circulante  Biblioteca Central Zila Mamede                         ESPECIAL         638          1                   1
# 1070480      2013071582     Acervo Circulante  Biblioteca Setorial do Centro Ciências da Saúde - CCS  REGULAR          340          200283              1
# 1070506      2013077711     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          354          200288              1
# 1070505      2013077710     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          327          200288              1
# 1070504      2013077807     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          348          200286              1
#                                                                                                                                                        ..
# 232120       2007034699     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          652          96457               1
# 232119       2007034703     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          628          96456               1
# 232118       2007036783     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          618          96301               1
# 232117       2007040275     Acervo Circulante  Biblioteca Central Zila Mamede                         REGULAR          680          96301               1
# 1353476      2019012276     Acervo Circulante  Biblioteca Central Zila Mamede                         ESPECIAL         962          268236              1
# Name: count, Length: 546237, dtype: int64

# %%
duplicados_dados_exemplares = dados_exemplares.duplicated()
duplicados_dados_exemplares.sum()

# %% [markdown]
# ## **Verificando dados nulos**

# %%
dados_exemplares.isnull().sum()
# Out:
# id_exemplar         0
# codigo_barras       0
# colecao             0
# biblioteca          0
# status_material     0
# localizacao         0
# registro_sistema    0
# dtype: int64

# %% [markdown]
# ## **Unindo os DataFrames**

# %%
emprestimos_completos = pd.merge(emprestimos_biblioteca, dados_exemplares)

# %%
emprestimos_completos
# Out:
#          id_emprestimo                codigo_barras  \
# 1               809804  S025602_19/11/2013 10:51:34
# 5               853966  S025602_19/11/2013 10:51:34
# 8               711727  S025602_19/11/2013 10:51:34
# 9               719294  S025602_19/11/2013 10:51:34
# 13              921416  S025602_19/11/2013 10:51:34
# ...                ...                          ...
# 2072496        2988739                   2016000708
# 2072502        2988811                   2015033958
# 2072503        2988812                   2016019436
# 2072507        2988874                   2010080699
# 2072516        2988968                   2016033194
#
#                         data_renovacao                data_emprestimo  \
# 1        2010/08/10 20:36:21.378000000  2010/08/09 14:32:14.211000000
# 5        2010/10/22 00:38:01.674000000  2010/10/11 17:31:19.059000000
# 8        2010/01/28 11:18:24.559000000  2010/01/14 13:18:24.082000000
# 9        2010/03/08 18:49:27.364000000  2010/02/22 08:31:43.331000000
# 13       2011/02/21 12:33:55.109000000  2011/01/21 09:40:50.712000000
# ...                                ...                            ...
# 2072496  2020/04/17 22:49:24.993000000  2020/03/17 15:22:53.701000000
# 2072502  2020/04/26 11:43:40.087000000  2020/03/17 16:20:01.906000000
# 2072503  2020/04/26 11:43:40.062000000  2020/03/17 16:20:01.992000000
# 2072507  2021/08/10 02:30:14.871000000  2020/03/17 17:07:40.834000000
# 2072516  2020/04/06 18:21:57.168000000  2020/03/17 18:33:29.752000000
#
#                         data_devolucao  matricula_ou_siape  \
# 1        2010/08/30 17:04:59.000000000        2.008035e+09
# 5        2010/11/04 07:58:04.000000000        2.006219e+08
# 8        2010/02/09 09:31:01.871000000        2.010081e+09
# 9        2010/03/23 12:35:37.367000000        2.006341e+08
# 13       2011/03/14 15:47:08.000000000        2.008109e+09
# ...                                ...                 ...
# 2072496  2021/04/19 13:54:01.000000000        2.019201e+10
# 2072502  2021/06/09 12:33:33.000000000        2.016103e+10
# 2072503  2021/06/09 12:33:39.000000000        2.016103e+10
# 2072507  2022/02/17 11:48:53.000000000        2.017015e+10
# 2072516  2021/06/15 16:52:35.000000000        2.016014e+10
#
#            tipo_vinculo_usuario  id_exemplar            colecao  \
# 1            ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# 5            ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# 8            ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# 9            ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# 13       ALUNO DE PÓS-GRADUAÇÃO       186525  Acervo Circulante
# ...                         ...          ...                ...
# 2072496  ALUNO DE PÓS-GRADUAÇÃO      1237017  Acervo Circulante
# 2072502  ALUNO DE PÓS-GRADUAÇÃO      1211606  Acervo Circulante
# 2072503  ALUNO DE PÓS-GRADUAÇÃO      1235460  Acervo Circulante
# 2072507      ALUNO DE GRADUAÇÃO       826353  Acervo Circulante
# 2072516      ALUNO DE GRADUAÇÃO      1310816  Acervo Circulante
#
#                                                 biblioteca status_material  \
# 1                           Biblioteca Central Zila Mamede         REGULAR
# 5                           Biblioteca Central Zila Mamede         REGULAR
# 8                           Biblioteca Central Zila Mamede         REGULAR
# 9                           Biblioteca Central Zila Mamede         REGULAR
# 13                          Biblioteca Central Zila Mamede         REGULAR
# ...                                                    ...             ...
# 2072496  Biblioteca Setorial Profª. Maria José Mamede G...         REGULAR
# 2072502                     Biblioteca Central Zila Mamede         REGULAR
# 2072503                     Biblioteca Central Zila Mamede         REGULAR
# 2072507                     Biblioteca Central Zila Mamede         REGULAR
# 2072516  Biblioteca Setorial da Faculdade de Ciências d...         REGULAR
#
#          localizacao  registro_sistema
# 1                635             71668
# 5                635             71668
# 8                635             71668
# 9                635             71668
# 13               635             71668
# ...              ...               ...
# 2072496          569            234061
# 2072502          541            227626
# 2072503          511            233523
# 2072507          660            134891
# 2072516          785            253484
#
# [906412 rows x 13 columns]

# %% [markdown]
# ## **Verificando informações do DataFrame**

# %%
emprestimos_completos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072522 entries, 0 to 2072521
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  registro_sistema      int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 205.6+ MB

# %% [markdown]
# ## **Excluindo nulos**

# %%
emprestimos_completos.dropna(inplace=True)

# %% [markdown]
# ## **Definindo o nome da coluna conforme a Classificação Decimal Universal (CDU)**

# %%
CDU_lista = []
for CDU in emprestimos_completos['localizacao']:
  if(CDU < 100):
    CDU_lista.append('Generalidades')
  elif(CDU < 200):
    CDU_lista.append('Filosofia e psicologia')
  elif(CDU < 300):
    CDU_lista.append('Religião')
  elif(CDU < 400):
    CDU_lista.append('Ciências sociais')
  elif(CDU < 500):
    CDU_lista.append('Classe vaga')
  elif(CDU < 600):
    CDU_lista.append('Matemática e ciências naturais')
  elif(CDU < 700):
    CDU_lista.append('Ciências aplicadas')
  elif(CDU < 800):
    CDU_lista.append('Belas artes')
  elif(CDU < 900):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia. Biografia. História.')

emprestimos_completos['CDU_geral'] = CDU_lista

# %%
emprestimos_completos
# Out:
#          id_emprestimo                codigo_barras  \
# 1               809804  S025602_19/11/2013 10:51:34
# 5               853966  S025602_19/11/2013 10:51:34
# 8               711727  S025602_19/11/2013 10:51:34
# 9               719294  S025602_19/11/2013 10:51:34
# 13              921416  S025602_19/11/2013 10:51:34
# ...                ...                          ...
# 2072496        2988739                   2016000708
# 2072502        2988811                   2015033958
# 2072503        2988812                   2016019436
# 2072507        2988874                   2010080699
# 2072516        2988968                   2016033194
#
#                         data_renovacao                data_emprestimo  \
# 1        2010/08/10 20:36:21.378000000  2010/08/09 14:32:14.211000000
# 5        2010/10/22 00:38:01.674000000  2010/10/11 17:31:19.059000000
# 8        2010/01/28 11:18:24.559000000  2010/01/14 13:18:24.082000000
# 9        2010/03/08 18:49:27.364000000  2010/02/22 08:31:43.331000000
# 13       2011/02/21 12:33:55.109000000  2011/01/21 09:40:50.712000000
# ...                                ...                            ...
# 2072496  2020/04/17 22:49:24.993000000  2020/03/17 15:22:53.701000000
# 2072502  2020/04/26 11:43:40.087000000  2020/03/17 16:20:01.906000000
# 2072503  2020/04/26 11:43:40.062000000  2020/03/17 16:20:01.992000000
# 2072507  2021/08/10 02:30:14.871000000  2020/03/17 17:07:40.834000000
# 2072516  2020/04/06 18:21:57.168000000  2020/03/17 18:33:29.752000000
#
#                         data_devolucao  matricula_ou_siape  \
# 1        2010/08/30 17:04:59.000000000        2.008035e+09
# 5        2010/11/04 07:58:04.000000000        2.006219e+08
# 8        2010/02/09 09:31:01.871000000        2.010081e+09
# 9        2010/03/23 12:35:37.367000000        2.006341e+08
# 13       2011/03/14 15:47:08.000000000        2.008109e+09
# ...                                ...                 ...
# 2072496  2021/04/19 13:54:01.000000000        2.019201e+10
# 2072502  2021/06/09 12:33:33.000000000        2.016103e+10
# 2072503  2021/06/09 12:33:39.000000000        2.016103e+10
# 2072507  2022/02/17 11:48:53.000000000        2.017015e+10
# 2072516  2021/06/15 16:52:35.000000000        2.016014e+10
#
#            tipo_vinculo_usuario  id_exemplar            colecao  \
# 1            ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# 5            ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# 8            ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# 9            ALUNO DE GRADUAÇÃO       186525  Acervo Circulante
# 13       ALUNO DE PÓS-GRADUAÇÃO       186525  Acervo Circulante
# ...                         ...          ...                ...
# 2072496  ALUNO DE PÓS-GRADUAÇÃO      1237017  Acervo Circulante
# 2072502  ALUNO DE PÓS-GRADUAÇÃO      1211606  Acervo Circulante
# 2072503  ALUNO DE PÓS-GRADUAÇÃO      1235460  Acervo Circulante
# 2072507      ALUNO DE GRADUAÇÃO       826353  Acervo Circulante
# 2072516      ALUNO DE GRADUAÇÃO      1310816  Acervo Circulante
#
#                                                 biblioteca status_material  \
# 1                           Biblioteca Central Zila Mamede         REGULAR
# 5                           Biblioteca Central Zila Mamede         REGULAR
# 8                           Biblioteca Central Zila Mamede         REGULAR
# 9                           Biblioteca Central Zila Mamede         REGULAR
# 13                          Biblioteca Central Zila Mamede         REGULAR
# ...                                                    ...             ...
# 2072496  Biblioteca Setorial Profª. Maria José Mamede G...         REGULAR
# 2072502                     Biblioteca Central Zila Mamede         REGULAR
# 2072503                     Biblioteca Central Zila Mamede         REGULAR
# 2072507                     Biblioteca Central Zila Mamede         REGULAR
# 2072516  Biblioteca Setorial da Faculdade de Ciências d...         REGULAR
#
#          localizacao  registro_sistema                       CDU_geral
# 1                635             71668              Ciências aplicadas
# 5                635             71668              Ciências aplicadas
# 8                635             71668              Ciências aplicadas
# 9                635             71668              Ciências aplicadas
# 13               635             71668              Ciências aplicadas
# ...              ...               ...                             ...
# 2072496          569            234061  Matemática e ciências naturais
# 2072502          541            227626  Matemática e ciências naturais
# 2072503          511            233523  Matemática e ciências naturais
# 2072507          660            134891              Ciências aplicadas
# 2072516          785            253484                     Belas artes
#
# [906412 rows x 14 columns]

# %% [markdown]
# ## **Deletando coluna 'registro_sistema'**

# %%
emprestimos_completos.drop(columns=['registro_sistema'], inplace= True)

# %% [markdown]
# ## **Modificando o tipo de dado da coluna 'matricula'**

# %%
emprestimos_completos['matricula_ou_siape'] = emprestimos_completos['matricula_ou_siape'].astype(str)

# %%
emprestimos_completos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 906412 entries, 1 to 2072516
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         906412 non-null  int64
#  1   codigo_barras         906412 non-null  object
#  2   data_renovacao        906412 non-null  object
#  3   data_emprestimo       906412 non-null  object
#  4   data_devolucao        906412 non-null  object
#  5   matricula_ou_siape    906412 non-null  object
#  6   tipo_vinculo_usuario  906412 non-null  object
#  7   id_exemplar           906412 non-null  int64
#  8   colecao               906412 non-null  object
#  9   biblioteca            906412 non-null  object
#  10  status_material       906412 non-null  object
#  11  localizacao           906412 non-null  int64
#  12  CDU_geral             906412 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 96.8+ MB

# %% [markdown]
# ## **Perguntas e Respostas**

# %% [markdown]
# A diretoria da biblioteca gostaria de entender se a quantidade de empréstimos está diminuindo, aumentando ou permanecendo igual ao decorrer dos últimos anos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.ticker as ticker

# %%
emprestimos_completos['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 10114792    3
# 1987946     3
# 2772079     3
# 10240112    3
# 1775991     3
#            ..
# 971141      1
# 1178415     1
# 1438565     1
# 1680702     1
# 2988968     1
# Name: count, Length: 904866, dtype: int64

# %%
emprestimos_completos['id_emprestimo'].drop_duplicates()
# Out:
# 1           809804
# 5           853966
# 8           711727
# 9           719294
# 13          921416
#             ...
# 2072496    2988739
# 2072502    2988811
# 2072503    2988812
# 2072507    2988874
# 2072516    2988968
# Name: id_emprestimo, Length: 904866, dtype: int64

# %%
emprestimos_data = pd.DataFrame(emprestimos_completos['data_emprestimo'].value_counts()).reset_index()
emprestimos_data.columns = ['data','quantidade']
emprestimos_data['data'] = pd.to_datetime(emprestimos_data['data'])
emprestimos_data
# Out:
#                           data  quantidade
# 0      2018-11-22 18:28:01.619           3
# 1      2014-05-12 09:56:18.787           3
# 2      2017-09-20 16:47:09.285           3
# 3      2015-05-05 20:37:19.551           3
# 4      2017-11-06 19:52:32.782           3
# ...                        ...         ...
# 904856 2011-04-13 16:06:50.964           1
# 904857 2012-02-28 12:10:52.337           1
# 904858 2013-03-04 12:13:37.934           1
# 904859 2014-02-05 17:45:49.612           1
# 904860 2020-03-17 18:33:29.752           1
#
# [904861 rows x 2 columns]

# %%
emprestimos_ano = emprestimos_data.groupby(by=emprestimos_data['data'].dt.year).size()
emprestimos_ano.index.name = 'ano'
emprestimos_ano = emprestimos_ano.reset_index()
emprestimos_ano.columns = ['ano', 'quantidade']
emprestimos_ano['ano'] = pd.to_datetime(emprestimos_ano['ano'], format='%Y')
emprestimos_ano
# Out:
#           ano  quantidade
# 0  2010-01-01       71277
# 1  2011-01-01       93679
# 2  2012-01-01      103832
# 3  2013-01-01      105290
# 4  2014-01-01       94010
# 5  2015-01-01       85249
# 6  2016-01-01       94696
# 7  2017-01-01       93878
# 8  2018-01-01       81628
# 9  2019-01-01       73956
# 10 2020-01-01        7366

# %%
emprestimos_ano = emprestimos_data.groupby(by=emprestimos_data['data'].dt.year).size()
emprestimos_ano.index.name = 'ano'
emprestimos_ano
# Out:
# ano
# 2010     71277
# 2011     93679
# 2012    103832
# 2013    105290
# 2014     94010
# 2015     85249
# 2016     94696
# 2017     93878
# 2018     81628
# 2019     73956
# 2020      7366
# dtype: int64
